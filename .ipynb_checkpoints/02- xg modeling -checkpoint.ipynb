# %% [markdown]
# #### *Imports*

# %%
import os
import pandas as pd 
from xgboost import XGBClassifier
from sklearn.metrics import average_precision_score, roc_auc_score
from sklearn.model_selection import GridSearchCV, train_test_split
from scipy.spatial import distance

pd.set_option('display.max_columns', None)

# %%
shots_df= pd.read_parquet('data/shots/scisports-shots.parquet')
shots_df.head()
# Out:
#    action_game_id  action_team_id  action_player_id  action_period  \
# 0               0               6              5703              1
# 1               0               6              3726              1
# 2               0             281              2690              1
# 3               0               6              4070              1
# 4               0               6              6514              1
#
#    action_seconds  action_type_id action_type_name  action_body_part_id  \
# 0          188.23              11             shot                    0
# 1          609.31              11             shot                    0
# 2          969.28              11             shot                    0
# 3         1193.44              11             shot                    0
# 4         1359.36              11             shot                    1
#
#    action_result  action_start_x  action_start_y  action_end_x  action_end_y  \
# 0              0           98.75           40.17         105.0         40.85
# 1              0           84.20           48.48         105.0         27.40
# 2              0           92.68           46.52         105.0         41.08
# 3              0           94.40           46.14         104.9         37.30
# 4              0           93.52           27.95         105.0         40.87
#
#    action1_game_id  action1_team_id  action1_player_id  action1_period  \
# 0              0.0              6.0             3726.0             1.0
# 1              0.0              6.0             5797.0             1.0
# 2              0.0            281.0             6886.0             1.0
# 3              0.0              6.0             3726.0             1.0
# 4              0.0              6.0             6514.0             1.0
#
#    action1_seconds  action1_type_id action1_type_name  action1_body_part_id  \
# 0           187.75              1.0             cross                   0.0
# 1           607.57              0.0              pass                   0.0
# 2           967.00              0.0              pass                   0.0
# 3          1191.37              0.0              pass                   1.0
# 4          1357.96             21.0           dribble                   0.0
#
#    action1_result  action1_start_x  action1_start_y  action1_end_x  \
# 0             1.0            99.28            49.54          99.28
# 1             1.0            97.48            60.35          83.83
# 2             1.0            88.35            62.71          92.55
# 3             1.0            89.30            64.65          94.55
# 4             1.0            96.79            28.07          93.64
#
#    action1_end_y  action2_game_id  action2_team_id  action2_player_id  \
# 0          40.70              0.0              6.0             4070.0
# 1          48.11              0.0              6.0             3726.0
# 2          46.39              0.0            281.0             2690.0
# 3          46.29              0.0              6.0             5748.0
# 4          28.07              0.0              6.0             1015.0
#
#    action2_period  action2_seconds  action2_type_id action2_type_name  \
# 0             1.0           185.62              0.0              pass
# 1             1.0           606.29              0.0              pass
# 2             1.0           963.64              0.0              pass
# 3             1.0          1189.19              0.0              pass
# 4             1.0          1356.12              3.0  freekick_crossed
#
#    action2_body_part_id  action2_result  action2_start_x  action2_start_y  \
# 0                   0.0             1.0            93.53            65.36
# 1                   0.0             1.0            89.66            61.61
# 2                   0.0             1.0            72.30            60.37
# 3                   0.0             1.0            73.04            15.18
# 4                   0.0             1.0            79.67             6.67
#
#    action2_end_x  action2_end_y
# 0          98.78          49.04
# 1          98.06          60.93
# 2          88.05          62.41
# 3          88.79          64.14
# 4          96.47          27.75

# %%
for action in ['action', 'action1', 'action2']:
    for side in ['start', 'end']:
        
        # normalizing the X and Y coordinates 
        key_x = '{}_{}_x'.format(action, side)
        shots_df[key_x] = shots_df[key_x] / 105
        key_y = '{}_{}_y'.format(action, side)
        shots_df[key_y] = shots_df[key_y] / 68

# %%
goal= (0,1)

for action in ['action', 'action1', 'action2']:
    
    # inititating the names of columns we're going to add
    x = '{action}_start_x'.format(action=action)
    y = '{action}_start_y'.format(action=action)
    distance_ = '{action}_start_distance'.format(action=action)
    
    # adding the columns
    shots_df[distance_] = shots_df.apply(lambda s: distance.euclidean((s[x], s[y]), goal), axis=1)

# %%
# Features
features_columns = ['action_start_x', 'action_start_y', 'action_body_part_id', 'action_start_distance',
                    'action1_start_distance', 'action2_start_distance']

# labeling: 1 if a goal, 0 otherwise
column_target = 'action_result'

# %%
X = shots_df[features_columns]
y = shots_df[column_target]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10)

# %%
classifier = XGBClassifier(objective='binary:logistic', max_depth=5, n_estimators=100)
classifier.fit(X_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=None, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=5, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               multi_strategy=None, n_estimators=100, n_jobs=None,
#               num_parallel_tree=None, random_state=None, ...)

# %%
parameters = {
    'nthread': [4],
    'objective': ['binary:logistic'],
    'max_depth': [3, 4, 5, 6],
    'learning_rate': [0.01],
    'n_estimators': [100, 500, 1000],
    'seed': [42]
}

classifier = XGBClassifier()
classifier = GridSearchCV(classifier, parameters, scoring='roc_auc', verbose=2)
classifier.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.4s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   2.9s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   3.6s
# [CV] END learning_rate=0.01, max_depth=3, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   2.9s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.3s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.5s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   1.6s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   2.9s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   3.4s
# [CV] END learning_rate=0.01, max_depth=4, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   3.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   1.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.4s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.8s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.7s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.2s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.3s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   5.0s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   3.9s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   4.1s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   4.5s
# [CV] END learning_rate=0.01, max_depth=5, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   4.8s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   1.0s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.6s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=100, nthread=4, objective=binary:logistic, seed=42; total time=   0.9s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.5s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   4.4s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.6s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=500, nthread=4, objective=binary:logistic, seed=42; total time=   2.8s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   6.2s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   6.6s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   5.7s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   5.1s
# [CV] END learning_rate=0.01, max_depth=6, n_estimators=1000, nthread=4, objective=binary:logistic, seed=42; total time=   6.5s
# GridSearchCV(estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=None, device=None,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=None, max_b...
#                                      max_delta_step=None, max_depth=None,
#                                      max_leaves=None, min_child_weight=None,
#                                      missing=nan, monotone_constraints=None,
#                                      multi_strategy=None, n_estimators=None,
#                                      n_jobs=None, num_parallel_tree=None,
#                                      random_state=None, ...),
#              param_grid={'learning_rate': [0.01], 'max_depth': [3, 4, 5, 6],
#                          'n_estimators': [100, 500, 1000], 'nthread': [4],
#                          'objective': ['binary:logistic'], 'seed': [42]},
#              scoring='roc_auc', verbose=2)

# %%
y_pred = classifier.predict_proba(X_test)

# %%
y_total = y_train.count()
y_positive = y_train.sum()

print('The training set contains {} examples of which {} are positives.'.format(y_total, y_positive))
# Out:
# The training set contains 114878 examples of which 12183 are positives.

# %%
auc_roc = roc_auc_score(y_test, y_pred[:, 1])

print('Our classifier obtains an AUC-ROC of {}.'.format(auc_roc))
# Out:
# Our classifier obtains an AUC-ROC of 0.7764018308784635.

# %%
auc_pr_baseline = y_positive / y_total

print('The baseline performance for AUC-PR is {}.'.format(auc_pr_baseline))
# Out:
# The baseline performance for AUC-PR is 0.10605163738923032.

# %%
auc_pr = average_precision_score(y_test, y_pred[:, 1])

print('Our classifier obtains an AUC-PR of {}.'.format(auc_pr))
# Out:
# Our classifier obtains an AUC-PR of 0.3503478677325511.

# %%
from scikitplot.metrics import plot_roc_curve
from scikitplot.metrics import plot_precision_recall_curve
from scikitplot.metrics import plot_calibration_curve

# %%
plot_roc_curve(y_test, y_pred, curves='each_class')
# Out:
# /home/dahbi/anaconda3/lib/python3.11/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_roc_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_roc instead.
#   warnings.warn(msg, category=FutureWarning)
# <Axes: title={'center': 'ROC Curves'}, xlabel='False Positive Rate', ylabel='True Positive Rate'>

# %%
plot_precision_recall_curve(y_test, y_pred, curves='each_class')
# Out:
# /home/dahbi/anaconda3/lib/python3.11/site-packages/sklearn/utils/deprecation.py:86: FutureWarning: Function plot_precision_recall_curve is deprecated; This will be removed in v0.5.0. Please use scikitplot.metrics.plot_precision_recall instead.
#   warnings.warn(msg, category=FutureWarning)
# <Axes: title={'center': 'Precision-Recall Curve'}, xlabel='Recall', ylabel='Precision'>

# %%
plot_calibration_curve(y_test, [y_pred])
# Out:
# <Axes: title={'center': 'Calibration plots (Reliability Curves)'}, xlabel='Mean predicted value', ylabel='Fraction of positives'>
